# %%
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/kajojan/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/kajojan/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/kajojan/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/kajojan/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/kajojan/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# ...

# %%
file_content = open("zad1.txt").read()
tokens = nltk.word_tokenize(file_content.lower())
print(tokens)
print(len(tokens))
# Out:
# ['the', 'crazy', 'plan', 'to', 'explode', 'a', 'nuclear', 'bomb', 'on', 'the', 'moon', 'hydrogen', 'bomb', 'explosion', '(', 'credit', ':', 'getty', 'images', ')', 'by', 'mark', 'piesing', '8th', 'may', '2023', 'in', 'the', '1950s', ',', 'with', 'the', 'ussr', 'seemingly', 'sprinting', 'ahead', 'in', 'the', 'space', 'race', ',', 'us', 'scientists', 'hatched', 'a', 'bizarre', 'plan', 'â€', '“', 'nuking', 'the', 'surface', 'of', 'the', 'moon', 'to', 'frighten', 'the', 'soviets', '.', 't', 'the', 'moment', 'astronaut', 'neil', 'armstrong', 'stepped', 'out', 'on', 'to', 'the', 'moon', "'s", 'surface', 'in', '1969', 'is', 'one', 'of', 'the', 'most', 'memorable', 'moments', 'in', 'history', '.', 'but', 'what', 'if', 'the', 'moon', 'armstrong', 'stepped', 'onto', 'was', 'scarred', 'by', 'huge', 'craters', 'and', 'poisoned', 'from', 'the', 'effects', 'of', 'nuclear', 'bombardment', '?', 'at', 'first', 'reading', ',', 'the', 'title', 'of', 'the', 'research', 'paper', 'â€', '“', 'a', 'study', 
# ...

# %%
from nltk.corpus import stopwords

filtered_tokes = [token for token in tokens if token not in stopwords.words('english')]
print(filtered_tokes)
print(len(filtered_tokes))
# Out:
# ['crazy', 'plan', 'explode', 'nuclear', 'bomb', 'moon', 'hydrogen', 'bomb', 'explosion', '(', 'credit', ':', 'getty', 'images', ')', 'mark', 'piesing', '8th', 'may', '2023', '1950s', ',', 'ussr', 'seemingly', 'sprinting', 'ahead', 'space', 'race', ',', 'us', 'scientists', 'hatched', 'bizarre', 'plan', 'â€', '“', 'nuking', 'surface', 'moon', 'frighten', 'soviets', '.', 'moment', 'astronaut', 'neil', 'armstrong', 'stepped', 'moon', "'s", 'surface', '1969', 'one', 'memorable', 'moments', 'history', '.', 'moon', 'armstrong', 'stepped', 'onto', 'scarred', 'huge', 'craters', 'poisoned', 'effects', 'nuclear', 'bombardment', '?', 'first', 'reading', ',', 'title', 'research', 'paper', 'â€', '“', 'study', 'lunar', 'research', 'flights', ',', 'vol', '1', 'â€', '“', 'sounds', 'blandly', 'bureaucratic', 'peaceful', '.', 'kind', 'paper', 'easy', 'ignore', '.', 'probably', 'point', '.', 'glance', 'cover', ',', 'however', ',', 'things', 'look', 'little', 'different', '.', 'emblazoned', 'centre', 'sh
# ...

# %%
stopwords2 = ['.',"'s", ')', '(', ",", '“', 'â€', ":", "getty",  "''", '``', '...', "'", ';', '?', "'ve", 'u', 'u', "n't"]

filtered_tokes2 = [token for token in filtered_tokes if token not in stopwords2]
print(filtered_tokes2)
print(len(filtered_tokes2))
# Out:
# ['crazy', 'plan', 'explode', 'nuclear', 'bomb', 'moon', 'hydrogen', 'bomb', 'explosion', 'credit', 'images', 'mark', 'piesing', '8th', 'may', '2023', '1950s', 'ussr', 'seemingly', 'sprinting', 'ahead', 'space', 'race', 'us', 'scientists', 'hatched', 'bizarre', 'plan', 'nuking', 'surface', 'moon', 'frighten', 'soviets', 'moment', 'astronaut', 'neil', 'armstrong', 'stepped', 'moon', 'surface', '1969', 'one', 'memorable', 'moments', 'history', 'moon', 'armstrong', 'stepped', 'onto', 'scarred', 'huge', 'craters', 'poisoned', 'effects', 'nuclear', 'bombardment', 'first', 'reading', 'title', 'research', 'paper', 'study', 'lunar', 'research', 'flights', 'vol', '1', 'sounds', 'blandly', 'bureaucratic', 'peaceful', 'kind', 'paper', 'easy', 'ignore', 'probably', 'point', 'glance', 'cover', 'however', 'things', 'look', 'little', 'different', 'emblazoned', 'centre', 'shield', 'depicting', 'atom', 'nuclear', 'bomb', 'mushroom', 'cloud', 'emblem', 'air', 'force', 'special', 'weapons', 'center', 'k
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokes2]

print(lemmatized_tokens)
print(len(lemmatized_tokens))
# Out:
# ['crazy', 'plan', 'explode', 'nuclear', 'bomb', 'moon', 'hydrogen', 'bomb', 'explosion', 'credit', 'image', 'mark', 'piesing', '8th', 'may', '2023', '1950s', 'ussr', 'seemingly', 'sprinting', 'ahead', 'space', 'race', 'u', 'scientist', 'hatched', 'bizarre', 'plan', 'nuking', 'surface', 'moon', 'frighten', 'soviet', 'moment', 'astronaut', 'neil', 'armstrong', 'stepped', 'moon', 'surface', '1969', 'one', 'memorable', 'moment', 'history', 'moon', 'armstrong', 'stepped', 'onto', 'scarred', 'huge', 'crater', 'poisoned', 'effect', 'nuclear', 'bombardment', 'first', 'reading', 'title', 'research', 'paper', 'study', 'lunar', 'research', 'flight', 'vol', '1', 'sound', 'blandly', 'bureaucratic', 'peaceful', 'kind', 'paper', 'easy', 'ignore', 'probably', 'point', 'glance', 'cover', 'however', 'thing', 'look', 'little', 'different', 'emblazoned', 'centre', 'shield', 'depicting', 'atom', 'nuclear', 'bomb', 'mushroom', 'cloud', 'emblem', 'air', 'force', 'special', 'weapon', 'center', 'kirtland', '
# ...

# %%
from collections import Counter
import matplotlib.pyplot as plt

word_counts = Counter(lemmatized_tokens)

most_common = word_counts.most_common(10)
print(most_common)
labels, values = zip(*most_common)
plt.bar(labels, values)
plt.xticks(rotation=45)
plt.show()
# Out:
# [('nuclear', 15), ('moon', 14), ('space', 14), ('u', 14), ('soviet', 12), ('bomb', 11), ('project', 10), ('launch', 9), ('image', 8), ('could', 8)]

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=800, height=800, background_color='white').generate_from_frequencies(word_counts)
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
